# %% [markdown]
# ## OpenAI SDK

# %% [markdown]
# ### Using API Key

# %%
import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

BASE_URL = os.getenv("OPENAI_BASE_URL")
API_KEY = os.getenv("AZURE_OPENAI_API_KEY")

# %%
model = ChatOpenAI(
    base_url=BASE_URL,
    api_key=API_KEY,
    model="gpt-4o",
)

result = model.invoke("What is the capital of India?")
result.content
# Out:
# 'The capital of India is New Delhi.'

# %% [markdown]
# ### Using Entra ID
#
# via OpenAI SDK

# %%
TENANT_ID = os.getenv('AZURE_TENANT_ID')

# %%
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

token_provider = get_bearer_token_provider(
    DefaultAzureCredential(),
    "https://cognitiveservices.azure.com/.default",
)

# %%
model = ChatOpenAI(
    model = 'gpt-4o',
    base_url = BASE_URL,
    api_key = token_provider,
)

# %%
result = model.invoke("What is the capital of Japan")
print(result.content)
# Out:
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Please run "Connect-AzAccount" to set up account
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result = model.invoke("What is the capital of Japan")
#       2 print(result.content)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:472, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     458 @override
#     459 def invoke(
#     460     self,
#    (...)    465     **kwargs: Any,
#     466 ) -> AIMessage:
#     467     config = ensure_config(config)
#     468     return cast(
#     469         "AIMessage",
#     470         cast(
#     471             "ChatGeneration",
# --> 472             self.generate_prompt(
#     473                 [self._convert_input(input)],
#     474                 stop=stop,
#     475                 callbacks=config.get("callbacks"),
#     476                 tags=config.get("tags"),
#     477                 metadata=config.get("metadata"),
#     478                 run_name=config.get("run_name"),
#     479                 run_id=config.pop("run_id", None),
#     480                 **kwargs,
#     481             ).generations[0][0],
#     482         ).message,
#     483     )
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1752, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1743 @override
#    1744 def generate_prompt(
#    1745     self,
#    (...)   1749     **kwargs: Any,
#    1750 ) -> LLMResult:
#    1751     prompt_messages = [p.to_messages() for p in prompts]
# -> 1752     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1559, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1556 for i, m in enumerate(input_messages):
#    1557     try:
#    1558         results.append(
# -> 1559             self._generate_with_cache(
#    1560                 m,
#    1561                 stop=stop,
#    1562                 run_manager=run_managers[i] if run_managers else None,
#    1563                 **kwargs,
#    1564             )
#    1565         )
#    1566     except BaseException as e:
#    1567         if run_managers:
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1899, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1897     result = generate_from_stream(iter(chunks))
#    1898 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1899     result = self._generate(
#    1900         messages, stop=stop, run_manager=run_manager, **kwargs
#    1901     )
#    1902 else:
#    1903     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1659, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1657     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1658         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1659     raise e
#    1660 if (
#    1661     self.include_response_headers
#    1662     and raw_response is not None
#    1663     and hasattr(raw_response, "headers")
#    1664 ):
#    1665     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1650, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1643         return _construct_lc_result_from_responses_api(
#    1644             response,
#    1645             schema=original_schema_obj,
#    1646             metadata=generation_info,
#    1647             output_version=self.output_version,
#    1648         )
#    1649     else:
# -> 1650         raw_response = self.client.with_raw_response.create(**payload)
#    1651         response = raw_response.parse()
#    1652 except openai.BadRequestError as e:
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1212, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1165 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1166 def create(
#    1167     self,
#    (...)   1209     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1210 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1211     validate_response_format(response_format)
# -> 1212     return self._post(
#    1213         "/chat/completions",
#    1214         body=maybe_transform(
#    1215             {
#    1216                 "messages": messages,
#    1217                 "model": model,
#    1218                 "audio": audio,
#    1219                 "frequency_penalty": frequency_penalty,
#    1220                 "function_call": function_call,
#    1221                 "functions": functions,
#    1222                 "logit_bias": logit_bias,
#    1223                 "logprobs": logprobs,
#    1224                 "max_completion_tokens": max_completion_tokens,
#    1225                 "max_tokens": max_tokens,
#    1226                 "metadata": metadata,
#    1227                 "modalities": modalities,
#    1228                 "n": n,
#    1229                 "parallel_tool_calls": parallel_tool_calls,
#    1230                 "prediction": prediction,
#    1231                 "presence_penalty": presence_penalty,
#    1232                 "prompt_cache_key": prompt_cache_key,
#    1233                 "prompt_cache_retention": prompt_cache_retention,
#    1234                 "reasoning_effort": reasoning_effort,
#    1235                 "response_format": response_format,
#    1236                 "safety_identifier": safety_identifier,
#    1237                 "seed": seed,
#    1238                 "service_tier": service_tier,
#    1239                 "stop": stop,
#    1240                 "store": store,
#    1241                 "stream": stream,
#    1242                 "stream_options": stream_options,
#    1243                 "temperature": temperature,
#    1244                 "tool_choice": tool_choice,
#    1245                 "tools": tools,
#    1246                 "top_logprobs": top_logprobs,
#    1247                 "top_p": top_p,
#    1248                 "user": user,
#    1249                 "verbosity": verbosity,
#    1250                 "web_search_options": web_search_options,
#    1251             },
#    1252             completion_create_params.CompletionCreateParamsStreaming
#    1253             if stream
#    1254             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1255         ),
#    1256         options=make_request_options(
#    1257             extra_headers=extra_headers,
#    1258             extra_query=extra_query,
#    1259             extra_body=extra_body,
#    1260             timeout=timeout,
#    1261             security={"bearer_auth": True},
#    1262         ),
#    1263         cast_to=ChatCompletion,
#    1264         stream=stream or False,
#    1265         stream_cls=Stream[ChatCompletionChunk],
#    1266     )
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\_base_client.py:1019, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1017 for retries_taken in range(max_retries + 1):
#    1018     options = model_copy(input_options)
# -> 1019     options = self._prepare_options(options)
#    1021     remaining_retries = max_retries - retries_taken
#    1022     request = self._build_request(options, retries_taken=retries_taken)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\_client.py:499, in OpenAI._prepare_options(self, options)
#     496 @override
#     497 def _prepare_options(self, options: FinalRequestOptions) -> FinalRequestOptions:
#     498     if self._api_key_provider is not None and options.security.get("bearer_auth", False):
# --> 499         self._refresh_api_key()
#     501     return super()._prepare_options(options)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\openai\_client.py:505, in OpenAI._refresh_api_key(self)
#     503 def _refresh_api_key(self) -> str:
#     504     if self._api_key_provider is not None:
# --> 505         self.api_key = self._api_key_provider()
#     507     return self.api_key
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\azure\identity\_bearer_token_provider.py:43, in get_bearer_token_provider.<locals>.wrapper()
#      41 def wrapper() -> str:
#      42     request = _make_request()
# ---> 43     policy.on_request(request)
#      44     return request.http_request.headers["Authorization"][len("Bearer ") :]
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:167, in BearerTokenCredentialPolicy.on_request(self, request)
#     164 _enforce_https(request)
#     166 if self._token is None or self._need_new_token:
# --> 167     self._request_token(*self._scopes)
#     168 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     169 self._update_headers(request.http_request.headers, bearer_token)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:142, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     135 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     136     """Request a new token from the credential.
#     137
#     138     This will call the credential's appropriate method to get a token and store it in the policy.
#     139
#     140     :param str scopes: The type of access needed.
#     141     """
# --> 142     self._token = self._get_token(*scopes, **kwargs)
#     143     self._refresh_jitter = random.randint(0, MAX_REFRESH_JITTER_SECONDS)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:132, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#     129         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#     130             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# --> 132     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#     133 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\azure\identity\_credentials\default.py:376, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     374 within_dac.set(True)
#     375 try:
# --> 376     token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     377 finally:
#     378     within_dac.set(False)
#
# File c:\Data\Codes\Lanchain_Azure_openAI\.venv\Lib\site-packages\azure\identity\_credentials\chained.py:225, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     217 message = (
#     218     self.__class__.__name__
#     219     + " failed to retrieve a token from the included credentials."
#    (...)    222     "https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot."
#     223 )
#     224 _LOGGER.warning(message)
# --> 225 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Please run "Connect-AzAccount" to set up account
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
